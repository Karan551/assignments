# %% [markdown]
# Advance Operation With Business Example :-

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data Structure : [resturant_id,2021,2022,2023,2024]

sales_data=np.array([
    [1, 150000, 180000, 220000, 250000], # Paradise Biryani
    [2, 120000, 140000, 160000, 190000], # Bejing Bites
    [3, 200000, 230000, 260000, 300000], # Pizza Hub
    [4, 180000, 210000, 240000, 270000], # Burger Point
    [5, 160000, 185000, 205000, 230000]  # Chai Point
    ])
print("======Zomato Sales Analysis======")
print("Sales data shape::",sales_data.shape)
print("Sample data for 1st 3 resturant::\n",sales_data[:3])
# Out:
# ======Zomato Sales Analysis======
# Sales data shape:: (5, 5)
# Sample data for 1st 3 resturant::
#  [[     1 150000 180000 220000 250000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]

# %% [markdown]
# - axis=0 👉 column wise sum <br/>
# - axis=1 👉 row wise sum
# - Syntax for slicing of numpy array :-
#     - `data[row,column]`

# %%
# Total Sales Per year 
print(np.sum(sales_data,axis=0))

yearly_total_sales=np.sum(sales_data[:,1:],axis=0)
print("yearly total sales::\n",yearly_total_sales)

# minimum sales per year
min_sales=np.min(sales_data[:,1:],axis=0)
# print("minimum sales per year::",min_sales)

# minimum sales per resturant 
min_sales=np.min(sales_data[:,1:],axis=1)
# print("minimum sales per resturant::",min_sales)

# maximum sales per year
max_sales=np.max(sales_data[1],axis=0)
print("maximum sales::",max_sales)

# sum
total_value=np.sum(sales_data[:3,1:],axis=0)
print("this is total value::",total_value)
print()

# average sales per year
avg_sales=np.average(sales_data[:,1:],axis=0)
print("average sales per year::",avg_sales)
# average sales per resturant
avg_sales=np.average(sales_data[:,1:],axis=1)
print("average sales per resturant::\n",avg_sales)
# Out:
# [     15  810000  945000 1085000 1240000]
# yearly total sales::
#  [ 810000  945000 1085000 1240000]
# maximum sales:: 190000
# this is total value:: [470000 550000 640000 740000]
#
# average sales per year:: [162000. 189000. 217000. 248000.]
# average sales per resturant::
#  [200000. 152500. 247500. 225000. 195000.]

# %%
cumsum=np.cumsum(sales_data[:,1:],axis=1)
print("this is cumsum sales::\n",cumsum)
# Out:
# this is cumsum sales::
#  [[150000 330000 550000 800000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %% [markdown]
# - How To Draw Graph using matplotlib (overview) :-

# %%
cumsum=np.cumsum(sales_data[:,1:],axis=1)

plt.figure(figsize=(10,6))
plt.plot(np.mean(cumsum,axis=0))
plt.title("Average cumulative sales accross all restaurant")
plt.xlabel("Years")
plt.ylabel("Sales")
# 
plt.grid(True)
plt.show()

# %%
vector1 = np.array([1,2,3,4,5])
vector2 = np.array([6, 7, 8, 9, 10])
print("vector addition::\n",vector1+vector2)
print("Multiplication vector::\n", vector1 * vector2)
print("Dot Product::\n",np.dot(vector1,vector2))
# Out:
# vector addition::
#  [ 7  9 11 13 15]
# Multiplication vector::
#  [ 6 14 24 36 50]
# Dot Product::
#  130

# %%
# TODO: Here I have to work more methods
resturant_types=np.array(["biryani","pizza","burger","chinese","cafe"])
vectorize_upper=np.vectorize(str.upper)
vectorize_title=np.vectorize(str.title)
print("vectroized upper::\n",vectorize_upper(resturant_types))
print("vectroized title::\n",vectorize_title(resturant_types))
# Out:
# vectroized upper::
#  ['BIRYANI' 'PIZZA' 'BURGER' 'CHINESE' 'CAFE']
# vectroized title::
#  ['Biryani' 'Pizza' 'Burger' 'Chinese' 'Cafe']

# %%
monthly_avg=sales_data[:,1:]/12
print("this is monthly avg::\n",monthly_avg)
# Out:
# this is monthly avg::
#  [[12500.         15000.         18333.33333333 20833.33333333]
#  [10000.         11666.66666667 13333.33333333 15833.33333333]
#  [16666.66666667 19166.66666667 21666.66666667 25000.        ]
#  [15000.         17500.         20000.         22500.        ]
#  [13333.33333333 15416.66666667 17083.33333333 19166.66666667]]
